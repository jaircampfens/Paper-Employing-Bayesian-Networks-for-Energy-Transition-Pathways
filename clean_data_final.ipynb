# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
# !pip install pyreadstat

# Ignore all warnings
warnings.filterwarnings("ignore")
import pyreadstat

# %%
# Load the Data

import pandas as pd

# Step 1: Read the CSV file (you can adjust the options based on the earlier advice)
file_path = 'DataEDGE.csv'
df = pd.read_csv(file_path, engine='python', on_bad_lines='skip')  # Adjust engine and options as needed

# Step 2: Filter the DataFrame to only include rows where "Progress" is 100%
df_filt = df[df["Progress"] == 100.0]

# Step 3: Find columns that contain 'D1' in their name
df_filt_ans = df_filt.filter(like='D1', axis=1)

# Step 4: Display the re

# %%
# Find answer
df_filt_ans = df_filt.filter(like='D1', axis=1)
display(df_filt_ans)
# Out:
#      D1_1                            D1_2  \
# 0      No                             NaN
# 1     NaN  Yes, I have installed solar PV
# 2      No                             NaN
# 3      No                             NaN
# 4      No                             NaN
# ...   ...                             ...
# 4943   No                             NaN
# 4944   No                             NaN
# 4945  NaN                             NaN
# 4946   No                             NaN
# 4947   No                             NaN
#
#                                                 D1_4              D11_1  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
# ...

# %%
columns_to_keep = [

    'GDENAMK'

]

# %%
age_bins = [0, 30, 50, 70, 90]
media_bins = [0, 3.0, 6.0, 10.0]
people_bins = [0,2.0,6.0,7.1]
source_bins = [0,2.0,5.0,9.1]
economy_bins = [0,2.0,3.0,5.1]
# Create a new column 'age_category' with quartile labels
age_labels = ['very young', 'young', 'old', 'very old']
people_labels = ['low', 'medium', 'high']
source_labels = ['low', 'medium', 'high']
media_labels = ['low', 'medium', 'high']
economy_labels = ['low', 'medium', 'high']

# %%
# Define a dictionary for replacement
replacement_dict = {1: "yes", 0: "no"}

# List of binary columns
binary_columns = ["PV in the network",'PV adoption','Single familly house', 'Education level', 'Interest in politcs', 'Homeownership status', 'Electric car ownership', 'Heat pump ownership']

# Replace values in binary columns
df_info[binary_columns] = df_info[binary_columns].replace(replacement_dict)
df_info

# %%
df_info.dropna(inplace= True)
df_info

# %%
percentage_of_appearance = df_info['Number of people exchanged'].value_counts(normalize=True) * 100

# Printing the percentage of appearance for each unique value in the column
print("Percentage of appearance for each value in 'column_name':")
print(percentage_of_appearance)

# %%
from google.colab import files

# Download the file
files.download('DataEDGE.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-aedcdd0c55fb> in <cell line: 4>()
#       2
#       3 # Download the file
# ----> 4 files.download('DataEDGE.csv')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: DataEDGE.csv
